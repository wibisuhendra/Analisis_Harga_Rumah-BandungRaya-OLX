# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

f = open('linkolxrumah2.txt', 'r+')
links = [line for line in f.readlines()]
f.close()

# %%
links
# Out:
# ['/item/cluster-top-kota-bandung-strategis-dp-all-in-11-juta-iid-812073583\n',
#  '/item/perumahan-bandung-murah-2lantai-dekat-dengan-malltoldan-universitas-iid-811630196\n',
#  '/item/rumah-minimalis-di-chery-field-buah-batu-iid-779591226\n',
#  '/item/dijual-rumah-siap-huni-harga-akhir-tahun-di-cigadung-kota-bandung-iid-811987084\n',
#  '/item/perumahan-siap-bangun-murah-2-lantai-dekat-cicaheum-arcamanik-bandung-iid-812283134\n',
#  '/item/murah-rumah-antapani-dkt-gasmin-griya-superindo-antapani-iid-812282482\n',
#  '/item/rumah-dp-murah-proses-ga-ribet-cicilan-ringan-buah-batu-ciwastra-iid-812279046\n',
#  '/item/rumah-syariah-terbaik-insya-allah-amanah-rumahnya-barokah-di-ciwastra-iid-812278409\n',
#  '/item/rumahnya-oke-harga-bersahabat-pilihan-tepat-untuk-hunian-islami-iid-812278009\n',
#  '/item/dijual-cepat-rumah-siap-huni-iid-812277657\n',
#  '/item/limited-stock-rumah-mewah-cantik-ala-vila-sejuk-dkt-tol-pasteur-iid-812269997\n',
# ...

# %%
adsId = []
title = []
bedroom = []
bathroom = []
landsqr = []
buildingsqr = []
cert = []
loc = []
location = []
price = []
floor = []
postTime = []
numOfFac = []
fac = []
desc = []
url = []
badUrl = []

# %%
from urllib.error import URLError, HTTPError
from urllib.request import urlopen

# %%
for link in links:
    try:
        page = urlopen('https://www.olx.co.id'+link)
    except (URLError, HTTPError) as e:
        pass
        print(link)
        badUrl.append(link)
    else:
        soup = BeautifulSoup(page.read(),'html.parser')

        adsId.append(soup.find("strong").text)

        title.append(soup.find("h1",{'data-aut-id':"itemTitle"}).text)

        result = soup.find("span",{'data-aut-id':"value_p_bedroom"})
        bedroom.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_bathroom"})
        bathroom.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_sqr_land"})
        landsqr.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_sqr_building"})
        buildingsqr.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_certificate"})
        cert.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_alamat"})
        loc.append(result.text if result else "N/A")

        result = soup.find("span",{'class':"_2FRXm"})
        location.append(result.text if result else "N/A")

        result = soup.find("span",{"data-aut-id":"itemPrice"})
        price.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_floor"})
        floor.append(result.text if result else "N/A")

        result = soup.find("div",{'data-aut-id':"itemCreationDate"})
        postTime.append(result.text if result else "N/A")

        temp = soup.find_all("span",{"class":"_30Ijq"})

        numOfFac.append(len(temp) if temp else "N/A")
        p = ''
        if temp:
            for t in temp:
                p = p + ' ' +t.text+'|'

        fac.append(p if temp else "N/A")
        
        url.append(link)

        result = soup.find("div",{'data-aut-id':"itemDescriptionContent"})
        desc.append(result.text if result else "N/A")
#         time.sleep(3)
# Out:
# /item/cluster-top-kota-bandung-strategis-dp-all-in-11-juta-iid-812073583
#
# /item/promo-rumah-mewah-di-cimahi-utara-dekat-rsud-cibabat-booking-5-juta-iid-812269915
#
# /item/rumah-mewah-di-kota-cimahi-dekat-rsud-cibabat-free-design-iid-812269833
#
# /item/promo-rumah-modern-di-kota-cimahi-free-yamaha-n-max-tanpa-di-undi-iid-812269607
#
# /item/promo-spesial-akhir-tahun-rumah-cantik-di-cimahi-free-yamaha-n-max-iid-812269390
#
# /item/rumah-i-ndah-cantik-400jt-an-dkt-tol-bubatcipamolkolanstasiun-mrt-iid-812268853
#
# /item/rumah-impian-murah-dp-0-cashback-sd-40jt-di-cijambe-bandung-timur-iid-812266332
#
# /item/rumah-2-lantai-harga-murah-bonus-menarik-diciganitri-perumahan-syariah-iid-812263125
#
# /item/hunian-indah-400jt-an-dkt-tol-bubatstasiun-mrtkiaracondongcarefour-iid-812252743
#
# /item/rumah-murah-cimahi-padaasih-cisarua-ready-stock-siap-huni-ciawitali-iid-812244760
#
# /item/rumah-murah-bandung-cimahi-permana-kamarung-alun2-cibabat-pemkot-baros-iid-812243935
#
# ...

# %%
len(floor)
# Out:
# 8259

# %%
newLinks = badUrl.copy()

# %%
badUrl2 = []
for link in newLinks:
    try:
        page = urlopen('https://www.olx.co.id'+link)
    except (URLError, HTTPError) as e:
        pass
        print(link)
        badUrl2.append(link)
    else:
        soup = BeautifulSoup(page.read(),'html.parser')

        adsId.append(soup.find("strong").text)

        title.append(soup.find("h1",{'data-aut-id':"itemTitle"}).text)

        result = soup.find("span",{'data-aut-id':"value_p_bedroom"})
        bedroom.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_bathroom"})
        bathroom.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_sqr_land"})
        landsqr.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_sqr_building"})
        buildingsqr.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_certificate"})
        cert.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_alamat"})
        loc.append(result.text if result else "N/A")

        result = soup.find("span",{'class':"_2FRXm"})
        location.append(result.text if result else "N/A")

        result = soup.find("span",{"data-aut-id":"itemPrice"})
        price.append(result.text if result else "N/A")

        result = soup.find("span",{'data-aut-id':"value_p_floor"})
        floor.append(result.text if result else "N/A")

        result = soup.find("div",{'data-aut-id':"itemCreationDate"})
        postTime.append(result.text if result else "N/A")

        temp = soup.find_all("span",{"class":"_30Ijq"})

        numOfFac.append(len(temp) if temp else "N/A")
        p = ''
        if temp:
            for t in temp:
                p = p + ' ' +t.text+'|'

        fac.append(p if temp else "N/A")
        
        url.append(link)

        result = soup.find("div",{'data-aut-id':"itemDescriptionContent"})
        desc.append(result.text if result else "N/A")
#         time.sleep(3)
# Out:
# /item/cluster-top-kota-bandung-strategis-dp-all-in-11-juta-iid-812073583
#
# /item/promo-rumah-mewah-di-cimahi-utara-dekat-rsud-cibabat-booking-5-juta-iid-812269915
#
# /item/rumah-mewah-di-kota-cimahi-dekat-rsud-cibabat-free-design-iid-812269833
#
# /item/promo-rumah-modern-di-kota-cimahi-free-yamaha-n-max-tanpa-di-undi-iid-812269607
#
# /item/promo-spesial-akhir-tahun-rumah-cantik-di-cimahi-free-yamaha-n-max-iid-812269390
#
# /item/rumah-i-ndah-cantik-400jt-an-dkt-tol-bubatcipamolkolanstasiun-mrt-iid-812268853
#
# /item/rumah-impian-murah-dp-0-cashback-sd-40jt-di-cijambe-bandung-timur-iid-812266332
#
# /item/rumah-2-lantai-harga-murah-bonus-menarik-diciganitri-perumahan-syariah-iid-812263125
#
# /item/hunian-indah-400jt-an-dkt-tol-bubatstasiun-mrtkiaracondongcarefour-iid-812252743
#
# /item/rumah-murah-cimahi-padaasih-cisarua-ready-stock-siap-huni-ciawitali-iid-812244760
#
# /item/rumah-murah-bandung-cimahi-permana-kamarung-alun2-cibabat-pemkot-baros-iid-812243935
#
# ...

# %%
len(floor)
# Out:
# 8304

# %%
data = {'ID':adsId,'title':title,
    'bedroom':bedroom,  
    'bathroom':bathroom, 
    'landsqr':landsqr, 
    'buildingsqr':buildingsqr, 
    'cert':cert,
    'loc':loc,
    'location':location, 
    'floor':floor,
    'postTime':postTime,
    'numOfFac':numOfFac,
    'fac':fac,
    'desc':desc,
    'price':price,
    'url': url
}

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.to_csv(r'K:\\data analisis\\olxrumah2.csv')
